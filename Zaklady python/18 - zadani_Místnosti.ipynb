# %% [markdown]
# **Vytvořte Třídu Room, která bude obsahovat atributy:**
#
#
# 1. název
# 2. seznamExitu
# 3. poklad
# 4. nepritel
#
# **Vytvořte metody:**
#
#
# 1.   addExit, getNazev, getExity, getPoklad, getNepritel, toString
# 2.   setNazev

# %%
#TODO
class Room:
    def __init__(self,nazev):
        self.nazev = nazev
        self.seznam_exitu = []
        self.poklad = None
        self.nepritel = None
    def __str__(self):
        if self.poklad is not None:
            if self.nepritel is not None:
                return f"jsu v mistnosti {self.nazev} je tam poklad {self.poklad} a nepritel {self.nepritel}"
            else:
                return f"jsu v mistnosti {self.nazev} je tam poklad {self.poklad}"
        elif self.nepritel is not None:
            return f"jsu v mistnosti {self.nazev} je tam nepritel {self.nepritel}"
        else:
            return f"jsu v mistnosti {self.nazev} a je prazdna"
    def addExit(self,exit):
        self.seznam_exitu.append(exit)
    def getSeznamExitu(self):
        text=""
        for exit in self.seznam_exitu:
            text += exit.nazev + "\n"
        return text
    def seznamToString(self):
        text = ""
        for polozka in self.seznam_exitu:
            text += "{}\n".format(polozka)
        return text
    def getNepritel():

# %% [markdown]
# **Zde je vytvořená jednoduchá mapa s výpisy**

# %%
room1 = Room("Vstup do jeskyně")
room2 = Room("Jezírko")
room3 = Room("Předsíň draka")
room4 = Room("Dračí slůj")
room5 = Room("Vyhlídka")

room1.addExit(room5)
room5.addExit(room1)
room1.addExit(room2)
room1.addExit(room4)
room2.addExit(room1)
room4.addExit(room1)
room4.addExit(room3)
room4.addExit(room5)
room3.addExit(room4)
room5.addExit(room4)

aktualni = room1
print(aktualni.getSeznamExitu())
print(aktualni.getNepritel())
print(aktualni.getPoklad())
print(aktualni)

#chci se přesunout tak si změním aktualní na jeden z východu
aktualni = aktualni.seznamExitu[0]
print(aktualni)
#aktualni = aktualni.seznamExitu[2] # již nemá 3 exit --> skončí chybou
#print(aktualni)
aktualni = aktualni.seznamExitu[1]
print(aktualni)
# Out:
# Vyhlídka
# Jezírko
# Dračí slůj
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 20
#      18 aktualni = room1
#      19 print(aktualni.getSeznamExitu())
# ---> 20 print(aktualni.getNepritel())
#      21 print(aktualni.getPoklad())
#      22 print(aktualni)
#
# AttributeError: 'Room' object has no attribute 'getNepritel'
